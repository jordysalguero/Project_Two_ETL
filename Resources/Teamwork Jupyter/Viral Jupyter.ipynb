# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
AL = "Arable_Land.csv"
AL_df = pd.read_csv(AL)

AL_df.head()
# Out:
#   Country Name Country Code                Indicator Name  Indicator Code  \
# 0        Aruba          ABW  Arable land (% of land area)  AG.LND.ARBL.ZS
# 1  Afghanistan          AFG  Arable land (% of land area)  AG.LND.ARBL.ZS
# 2       Angola          AGO  Arable land (% of land area)  AG.LND.ARBL.ZS
# 3      Albania          ALB  Arable land (% of land area)  AG.LND.ARBL.ZS
# 4      Andorra          AND  Arable land (% of land area)  AG.LND.ARBL.ZS
#
#    1960       1961       1962       1963       1964       1965  ...  \
# 0   NaN  11.111111  11.111111  11.111111  11.111111  11.111111  ...
# 1   NaN  11.717673  11.794259  11.870845  11.947431  11.947431  ...
# 2   NaN   2.141654   2.165717   2.181760   2.205823   2.221866  ...
# 3   NaN  15.766423  15.912409  16.058394  16.167883  16.788321  ...
# 4   NaN   2.127660   2.127660   2.127660   2.127660   2.127660  ...
#
#         2009       2010       2011       2012       2013       2014  \
# ...

# %%
# Create a filtered dataframe from specific columns
AL_cols = ["Country Code", "Country Name", "2016"]
AL_transformed= AL_df[AL_cols].copy()

# Rename the column headers
AL_transformed =AL_transformed.rename(columns={"Country Code": "Country_Code", "Country Name": "Country_Name", "2016": "arable_land",
                                                          })

# Clean the data by dropping duplicates and setting the index
AL_transformed.drop_duplicates("Country_Name", inplace=True)
AL_transformed.set_index("Country_Name", inplace=True)
AL_transformed.dropna(inplace=True)
AL_transformed
# Out:
#                                Country_Code  arable_land
# Country_Name
# Aruba                                   ABW    11.111111
# Afghanistan                             AFG    11.838679
# Angola                                  AGO     3.930376
# Albania                                 ALB    22.638686
# Andorra                                 AND     1.659574
# Arab World                              ARB     3.515606
# United Arab Emirates                    ARE     0.626584
# Argentina                               ARG    14.323873
# Armenia                                 ARM    15.679663
# American Samoa                          ASM    15.000000
# Antigua and Barbuda                     ATG     9.090909
# Australia                               AUS     5.986464
# Austria                                 AUT    16.292307
# Azerbaijan                              AZE    24.180477
# Burundi                                 BDI    46.728972
# ...

# %%
engine = create_engine('mysql+mysqlconnector://root:alAlem@localhost:3306/Happiness_Indicators_2016')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['intellectual_property_transformed']

# %%
AL_transformed.to_sql(name='arable_land', con=engine, if_exists='append', index=True)
